# %%
from visTools_v2.core_functions.operations.img_grad import img_grad,load_img
from visTools_v2.core_functions.kernels.kernels import kernel
from visTools_v2.core_functions.edges import canny

# %%
import numpy as np
import matplotlib.pyplot as plt
import numpy.ma as ma
import math
import time

# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
def load_img(img):
    im = plt.imread(img)
    plt.imshow(im)
    plt.show()
    im = np.moveaxis(im,2,0)
    im = np.mean(im,axis=0)
    im = im[np.newaxis,np.newaxis,:,:]
    return im

# %%
im = load_img('img/blackline.png')
im1 = canny(sharp=False,
             blur=True,h=3,w=3,sig=1,th=0.03,Red=0)
im1.fit(im,nonMaxSup=False)
im1.plot()
im1.vector_field()
im1.vector_field(tan=True)

# %%
im = load_img('img/blackcircle.jpg')
im1 = canny(sharp=False,
             blur=True,h=3,w=3,sig=1,th=0.03,Red=0)
im1.fit(im,nonMaxSup=False)
im1.plot()
im1.vector_field(tan=True)

# %%
im = load_img('img/2viewp.jpg')
im1 = canny(sharp=False,
             blur=True,h=5,w=5,sig=1,th=.1,Red=0)
im1.fit(im)
im1.plot()
im1.vector_field(figsize=(10,16),tan=True)

# %%
im = load_img('img/canny.jpeg')
im1 = canny(sharp=False,
             blur=True,h=3,w=3,sig=1,th=.2,Red=0)
im1.fit(im)
im1.plot()
im1.vector_field(figsize=(10,16),tan=True)

# %%
im = load_img('img/uoft4.jpg')
im1 = canny(sharp=False,
             blur=True,h=11,w=11,sig=3,th=.2,Red=2)
im1.fit(im)
im1.plot()
im1.vector_field(figsize=(10,16),tan=True)

# %%
im = load_img('img/underwater-pipeline.jpg')
im1 = canny(sharp=False,
             blur=True,g=kernel().sobel,
             h=5,w=5,sig=0.5,th=.15,Red=0)
im1.fit(im,nonMaxSup=False)
im1.plot()
im1.vector_field(figsize=(10,16),tan=True)

# %%
im = load_img('img/luke.jpg')
im1 = canny(sharp=True,
             blur=True,g=kernel().sobel,h=3,w=3,sig=1,th=.1,Red=0)
im1.fit(im,nonMaxSup=False)
im1.plot()
im1.vector_field(figsize=(10,16),tan=True)
