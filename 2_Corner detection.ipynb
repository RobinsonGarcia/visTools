# %%
from src.corners import *
#from src.utilities import *
import matplotlib.pyplot as plt
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
bw_im = np.mean(plt.imread("img/chess.jpg"),axis=2)
corners = Harris()
corners.solve(bw_im/255,h=3,w=3,th=1e-5)

# %%
bw_im = np.mean(plt.imread("img/luke.jpg"),axis=2)
corners = Harris()
corners.solve(bw_im/255,h=3,w=3,th=1e-5)

# %%
im = plt.imread("img/church.jpg")
corners = Harris()
corners.solve(bw_im/255,h=3,w=3)

# %%
for i in np.arange(0.05,0.5,0.05):
    corners.apply_th(i)
