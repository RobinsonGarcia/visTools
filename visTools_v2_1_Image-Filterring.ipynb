# %%
from visTools_v2.core_functions.kernels.kernels import kernel
from visTools_v2.core_functions.operations.conv2d import conv2d
from visTools_v2.core_functions.kernels.gaussian_filter import *

# %%
import os
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# kernel():
#
#
# conv2d(

# %%
# %%capture
os.listdir('img')

# %%
im = Image.open('img/church.jpg')
im = np.array(im.resize((200,200)))

im = np.moveaxis(im,2,0)
im = im[np.newaxis,:,:]
im = np.mean(im,axis=1)[:,np.newaxis,:,:]

plt.imshow(im[0,0,:,:],**{'cmap':'gray'})

# %%
g = kernel()

# %%
plt.imshow(conv2d(im,g.sobel['x'])[0,0,:,:],**{'cmap':'gray'})

# %%
plt.imshow(conv2d(im,g.sobel['y'])[0,0,:,:],**{'cmap':'gray'})

# %%
plt.imshow(conv2d(im,g.mean)[0,0,:,:],**{'cmap':'gray'})

# %%
plt.imshow(conv2d(im,g.laplacian)[0,0,:,:],**{'cmap':'gray'})

# %%
plt.imshow(conv2d(im,g.gaussian)[0,0,:,:],**{'cmap':'gray'})

# %%
plt.imshow(conv2d(im,GaussianFilter(4,4,1.5)[np.newaxis,np.newaxis,:,:])[0,0,:,:],**{'cmap':'gray'})
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-f632d7895914> in <module>()
# ----> 1 plt.imshow(conv2d(im,GaussianFilter(4,4,1.5)[np.newaxis,np.newaxis,:,:])[0,0,:,:],**{'cmap':'gray'})
#
# ~/Documents/visTools/visTools_v2/core_functions/operations/conv2d.py in conv2d(x, w, stride)
#      83     out = np.rollaxis(out,0,3)
#      84
# ---> 85     out = np.reshape(out,(N,F,H2,W2))
#      86     ###########################################################################
#      87     ###########################################################################
#
# ~/anaconda3/lib/python3.6/site-packages/numpy/core/fromnumeric.py in reshape(a, newshape, order)
#     255            [5, 6]])
#     256     """
# --> 257     return _wrapfunc(a, 'reshape', newshape, order=order)
#     258
#     259
#
# ...
