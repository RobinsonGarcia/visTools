# %%
from src.canny import *
from src.robust_fit import *
import matplotlib.pyplot as plt
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

im = plt.imread("img/coins1.jpg")
bw_im = np.mean(im,axis=2)

# %%
canny1 = canny('img/coins1.jpg',deriv_type='fd',sharp=False,
             blur=True,h=5,w=5,sig=5/3,th=.3,Red=3)

# %%
pts = np.argwhere(canny1.mask)
pts = np.vstack((pts.T,np.ones(pts.shape[0]))).T

# %%
a = np.divide(normals[1],normals[0],out=np.zeros_like(normals[1]),where=normals[0]!=0)

a = a[pts[:,:2].astype(int)[:,0],pts[:,:2].astype(int)[:,1]]

b = pts[:,1] - pts[:,0]*a

l = np.array((-a,np.ones_like(a),-b)).T

idx = np.random.choice(np.arange(pts.shape[0]),2)
c = np.cross(l[idx[0]],l[idx[1]])
c/c[2]
# Out:
# array([55.9477892 , 76.74614438,  1.        ])

# %%
idx = np.random.choice(np.arange(pts.shape[0]),1)
#one = np.cross(l[idx[0]],l[idx[1]])

one = pts[idx].T
one = c[:2]/c[2]

plt.imshow(canny1.S)
plt.scatter(one[0],one[1])
det = 10

size=50
y_range = (pts[:,1] < int(one[1]+size)) & (pts[:,1] > int(one[1]-size))
x_range = (pts[:,0] < int(one[0]+size)) & (pts[:,0] > int(one[0]-size))


window = l[x_range&y_range]


plt.imshow(canny1.S)
det = 10
for i in range(1000):
    try:
        idx = np.random.choice(np.arange(window.shape[0]),3)
        selection = window[idx,:]
        v = np.cross(selection[0],selection[1])
        dist = v.dot(selection[2])

        if np.abs(dist)<det:
            keep = selection
            det = np.abs(dist)
            print(det)
    except:
        continue
    

center = np.cross(keep[0],keep[1])
center = center[:2]/center[2]
plt.imshow(canny1.S)


plt.scatter(center[0],center[1],color='red',s=20)
keep
# Out:
# 1.128682089055438
# 1.0254745225817032
# 0.9570064767804425
# 0.2880747268065704
# 0.12359641056900728
# 0.09662664918933839
# array([[   0.52600449,    1.        , -112.41015715],
#        [   0.57223141,    1.        , -159.20628128],
#        [   0.5025166 ,    1.        ,  -86.54278214]])

# %%
keep
# Out:
# array([[ 3.69214238e+01,  1.00000000e+00, -1.19756414e+03],
#        [ 3.69214238e+01,  1.00000000e+00, -1.19756414e+03],
#        [ 6.80306962e-01,  1.00000000e+00, -1.26900260e+02]])

# %%
np.linalg.det(selection.T)
# Out:
# 0.0

# %%
pts = np.argwhere(canny1.mask)
n = canny1.n

circles=[]
for i in range(10):
    N=0
    while N < 10:
        param,w,leverage = fit(pts,n,d=25,s=50,N=100,T=500,sigmaGM=30)
        
        if np.mean(leverage)<0.5:
            a,b,R=param
            inliers = np.sum((pts - (a,b))**2,axis=1) < R**2          
            circles.append(param)
            
            a,b=param[:2]
            R = param[2]
            plt.imshow(canny1.S,**{'cmap':'gray'})        
            circle = Circle((b,a),radius=R,color='red',fill=False,**{"linewidth":2})
            ax = plt.gca()
            ax.add_patch(circle)
            plt.axis('scaled')    
            
            pl.plot()
            display.clear_output(wait=True)
            display.display(pl.gcf())
            time.sleep(3.0)
            break
        N+=1
    
    pts = pts[~inliers]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-201-3d6aaf51d116> in <module>()
#       6     N=0
#       7     while N < 10:
# ----> 8         param,w,leverage = fit(pts,n,d=25,s=50,N=100,T=500,sigmaGM=30)
#       9
#      10         if np.mean(leverage)<0.5:
#
# ~/visTools/src/robust_fit.py in fit(pts, n, d, s, N, T, sigmaGM)
#     391     circles = get_proposals(pts,n,d,s,N,T)
#     392
# --> 393     best_circle,inliers = best_proposal(circles,pts,n,10)
#     394
#     395     param,w,leverage = IWLS(best_circle,pts[inliers],n,sigmaGM)
#
# ~/visTools/src/robust_fit.py in best_proposal(circles, pts, normals, sigmaGM)
#     375 def best_proposal(circles,pts,normals,sigmaGM):
#     376
# --> 377     di = pts[:,:,np.newaxis] - np.array(circles)[:,:2].T
#     378     di = np.sum(di**2,axis=1)
#     379
#
# IndexError: too many indices for array

# %%
normals = canny1.n

# %%
p = np.argwhere(canny1.mask)

# %%
p = np.array(p)

# %%
a=np.divide(normals[1],normals[0],out=np.zeros_like(normals[1]),where=normals[0]!=0)

# %%
a[p.T.tolist()]
# Out:
# array([  4.09759331,   5.96959195,   8.44320725, ..., -22.35168468,
#         -7.14142799,  -8.10100854])
