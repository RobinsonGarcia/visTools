# %%
from src.corners import *

# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import os
imgs = os.listdir("img/calibration/")
img = []
n=0
xks = []
for i in imgs:
    print('Image: {}'.format(i))
    print('Image #: {}'.format(n))
    img1 = Harris_detector(os.path.join(
    "img/calibration/",i))
    img1.solve(th=.09,clusters=98,Red=2,sharp=True)

    xks.append(img1.xk)
    n+=1
# Out:
# Image: IMG_20180914_194854.jpg
# Image #: 0
# Image: IMG_20180914_194903.jpg
# Image #: 1
# Image: IMG_20180914_194829.jpg
# Image #: 2
# Image: IMG_20180914_194845.jpg
# Image #: 3
# Image: IMG_20180914_194910.jpg
# Image #: 4
