# %%
from src.corners import *
#from src.utilities import *
import matplotlib.pyplot as plt
import os
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
root = 'img/calibration'
IMG = os.listdir(root)
print("Number of calibration images: {}".format(len(IMG)))
imgs=[]
i=1
for img in IMG:
    im = plt.imread(os.path.join(root,img))
    
    plt.subplot(3,2,i)
    plt.axis('off')
    plt.title(img)
    plt.imshow(im)
    i+=1
    imgs.append(im)
# Out:
# Number of calibration images: 5

# %%
bw_im = np.mean(im,axis=2)
corners = Harris()
corners.solve(bw_im/255,h=3,w=3,th=1e-5)
